# %%
import pandas as pd

# %% [markdown]
# ## Limpeza de dados 2021

# %%
dados_2021 = pd.read_csv(r"C:\Users\gabri\OneDrive\Documentos\2 periodo\intro. cd\projetosiconf\finbraRREO2021.csv", sep =";", skiprows=5,  encoding="latin1")

# %%
dados_2021
# Out:
#                                     Instituição  Cod.IBGE  UF  População  \
# 0      Prefeitura Municipal de Porto Velho - RO   1100205  RO     539354
# 1      Prefeitura Municipal de Porto Velho - RO   1100205  RO     539354
# 2      Prefeitura Municipal de Porto Velho - RO   1100205  RO     539354
# 3      Prefeitura Municipal de Porto Velho - RO   1100205  RO     539354
# 4      Prefeitura Municipal de Porto Velho - RO   1100205  RO     539354
# ...                                         ...       ...  ..        ...
# 10108       Prefeitura Municipal de Macapá - AP   1600303  AP     512902
# 10109       Prefeitura Municipal de Macapá - AP   1600303  AP     512902
# 10110       Prefeitura Municipal de Macapá - AP   1600303  AP     512902
# 10111       Prefeitura Municipal de Macapá - AP   1600303  AP     512902
# 10112       Prefeitura Municipal de Macapá - AP   1600303  AP     512902
#
#                          Coluna  \
# 0                       <MR-11>
# 1                       <MR-11>
# 2                       <MR-11>
# 3                       <MR-11>
# 4                       <MR-11>
# ...                         ...
# 10108  PREVISÃO ATUALIZADA 2021
# 10109  PREVISÃO ATUALIZADA 2021
# 10110  PREVISÃO ATUALIZADA 2021
# 10111  PREVISÃO ATUALIZADA 2021
# 10112  PREVISÃO ATUALIZADA 2021
#
#                                                    Conta  \
# 0                                 RECEITAS CORRENTES (I)
# 1            Impostos, Taxas e Contribuições de Melhoria
# 2                                                   IPTU
# 3                                                    ISS
# 4                                                   ITBI
# ...                                                  ...
# 10108   Contrib. do Servidor para o Plano de Previdência
# 10109         Dedução de Receita para Formação do FUNDEB
# 10110          RECEITA CORRENTE LÍQUIDA (III) = (I - II)
# 10111  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
# 10112  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
#
#                                   Identificador da Conta         Valor
# 0      siconfi-cor_ReceitasCorrentesLiquidasExcetoTra...  168295392,69
# 1      siconfi-cor_ReceitaTributariaLiquidaExcetoTran...   46427054,97
# 2      siconfi-cor_IPTULiquidoExcetoTransferenciasEFU...   16276431,81
# 3      siconfi-cor_ISSLiquidoExcetoTransferenciasEFUNDEB   11369867,25
# 4      siconfi-cor_ITBILiquidoExcetoTransferenciasEFU...    1220253,41
# ...                                                  ...           ...
# 10108  siconfi-cor_ContribuicaoDoServidorParaOPlanoDe...   27610496,00
# 10109   siconfi-cor_DeducaoDeReceitaParaFormacaoDoFUNDEB   95676468,00
# 10110            siconfi-cor_RREO3ReceitaCorrenteLiquida  903629507,00
# 10111  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...  903629507,00
# 10112  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...  903629507,00
#
# [10113 rows x 8 columns]

# %%
dados_2021 =dados_2021.drop(columns=['Cod.IBGE', 'Coluna'])
dados_2021
# Out:
#                                     Instituição  UF  População  \
# 0      Prefeitura Municipal de Porto Velho - RO  RO     539354
# 1      Prefeitura Municipal de Porto Velho - RO  RO     539354
# 2      Prefeitura Municipal de Porto Velho - RO  RO     539354
# 3      Prefeitura Municipal de Porto Velho - RO  RO     539354
# 4      Prefeitura Municipal de Porto Velho - RO  RO     539354
# ...                                         ...  ..        ...
# 10108       Prefeitura Municipal de Macapá - AP  AP     512902
# 10109       Prefeitura Municipal de Macapá - AP  AP     512902
# 10110       Prefeitura Municipal de Macapá - AP  AP     512902
# 10111       Prefeitura Municipal de Macapá - AP  AP     512902
# 10112       Prefeitura Municipal de Macapá - AP  AP     512902
#
#                                                    Conta  \
# 0                                 RECEITAS CORRENTES (I)
# 1            Impostos, Taxas e Contribuições de Melhoria
# 2                                                   IPTU
# 3                                                    ISS
# 4                                                   ITBI
# ...                                                  ...
# 10108   Contrib. do Servidor para o Plano de Previdência
# 10109         Dedução de Receita para Formação do FUNDEB
# 10110          RECEITA CORRENTE LÍQUIDA (III) = (I - II)
# 10111  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
# 10112  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
#
#                                   Identificador da Conta         Valor
# 0      siconfi-cor_ReceitasCorrentesLiquidasExcetoTra...  168295392,69
# 1      siconfi-cor_ReceitaTributariaLiquidaExcetoTran...   46427054,97
# 2      siconfi-cor_IPTULiquidoExcetoTransferenciasEFU...   16276431,81
# 3      siconfi-cor_ISSLiquidoExcetoTransferenciasEFUNDEB   11369867,25
# 4      siconfi-cor_ITBILiquidoExcetoTransferenciasEFU...    1220253,41
# ...                                                  ...           ...
# 10108  siconfi-cor_ContribuicaoDoServidorParaOPlanoDe...   27610496,00
# 10109   siconfi-cor_DeducaoDeReceitaParaFormacaoDoFUNDEB   95676468,00
# 10110            siconfi-cor_RREO3ReceitaCorrenteLiquida  903629507,00
# 10111  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...  903629507,00
# 10112  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...  903629507,00
#
# [10113 rows x 6 columns]

# %%
dados_2021['Valor'] = dados_2021['Valor'].str.replace('.', '', regex=False) 
dados_2021['Valor'] = dados_2021['Valor'].str.replace(',', '.', regex=False)

dados_2021['Valor'] = pd.to_numeric(dados_2021['Valor'], errors='coerce')

dados_2021['Valor'] = dados_2021['Valor'].apply(lambda x: f' {x:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'))

# %%
dados_2021
# Out:
#                                     Instituição  UF  População  \
# 0      Prefeitura Municipal de Porto Velho - RO  RO     539354
# 1      Prefeitura Municipal de Porto Velho - RO  RO     539354
# 2      Prefeitura Municipal de Porto Velho - RO  RO     539354
# 3      Prefeitura Municipal de Porto Velho - RO  RO     539354
# 4      Prefeitura Municipal de Porto Velho - RO  RO     539354
# ...                                         ...  ..        ...
# 10108       Prefeitura Municipal de Macapá - AP  AP     512902
# 10109       Prefeitura Municipal de Macapá - AP  AP     512902
# 10110       Prefeitura Municipal de Macapá - AP  AP     512902
# 10111       Prefeitura Municipal de Macapá - AP  AP     512902
# 10112       Prefeitura Municipal de Macapá - AP  AP     512902
#
#                                                    Conta  \
# 0                                 RECEITAS CORRENTES (I)
# 1            Impostos, Taxas e Contribuições de Melhoria
# 2                                                   IPTU
# 3                                                    ISS
# 4                                                   ITBI
# ...                                                  ...
# 10108   Contrib. do Servidor para o Plano de Previdência
# 10109         Dedução de Receita para Formação do FUNDEB
# 10110          RECEITA CORRENTE LÍQUIDA (III) = (I - II)
# 10111  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
# 10112  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
#
#                                   Identificador da Conta            Valor
# 0      siconfi-cor_ReceitasCorrentesLiquidasExcetoTra...   168.295.392,69
# 1      siconfi-cor_ReceitaTributariaLiquidaExcetoTran...    46.427.054,97
# 2      siconfi-cor_IPTULiquidoExcetoTransferenciasEFU...    16.276.431,81
# 3      siconfi-cor_ISSLiquidoExcetoTransferenciasEFUNDEB    11.369.867,25
# 4      siconfi-cor_ITBILiquidoExcetoTransferenciasEFU...     1.220.253,41
# ...                                                  ...              ...
# 10108  siconfi-cor_ContribuicaoDoServidorParaOPlanoDe...    27.610.496,00
# 10109   siconfi-cor_DeducaoDeReceitaParaFormacaoDoFUNDEB    95.676.468,00
# 10110            siconfi-cor_RREO3ReceitaCorrenteLiquida   903.629.507,00
# 10111  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...   903.629.507,00
# 10112  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...   903.629.507,00
#
# [10113 rows x 6 columns]

# %%
dados_2021.insert(0, 'Ano', 2021)
dados_2021
# Out:
#         Ano                               Instituição  UF  População  \
# 0      2021  Prefeitura Municipal de Porto Velho - RO  RO     539354
# 1      2021  Prefeitura Municipal de Porto Velho - RO  RO     539354
# 2      2021  Prefeitura Municipal de Porto Velho - RO  RO     539354
# 3      2021  Prefeitura Municipal de Porto Velho - RO  RO     539354
# 4      2021  Prefeitura Municipal de Porto Velho - RO  RO     539354
# ...     ...                                       ...  ..        ...
# 10108  2021       Prefeitura Municipal de Macapá - AP  AP     512902
# 10109  2021       Prefeitura Municipal de Macapá - AP  AP     512902
# 10110  2021       Prefeitura Municipal de Macapá - AP  AP     512902
# 10111  2021       Prefeitura Municipal de Macapá - AP  AP     512902
# 10112  2021       Prefeitura Municipal de Macapá - AP  AP     512902
#
#                                                    Conta  \
# 0                                 RECEITAS CORRENTES (I)
# 1            Impostos, Taxas e Contribuições de Melhoria
# 2                                                   IPTU
# 3                                                    ISS
# 4                                                   ITBI
# ...                                                  ...
# 10108   Contrib. do Servidor para o Plano de Previdência
# 10109         Dedução de Receita para Formação do FUNDEB
# 10110          RECEITA CORRENTE LÍQUIDA (III) = (I - II)
# 10111  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
# 10112  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
#
#                                   Identificador da Conta            Valor
# 0      siconfi-cor_ReceitasCorrentesLiquidasExcetoTra...   168.295.392,69
# 1      siconfi-cor_ReceitaTributariaLiquidaExcetoTran...    46.427.054,97
# 2      siconfi-cor_IPTULiquidoExcetoTransferenciasEFU...    16.276.431,81
# 3      siconfi-cor_ISSLiquidoExcetoTransferenciasEFUNDEB    11.369.867,25
# 4      siconfi-cor_ITBILiquidoExcetoTransferenciasEFU...     1.220.253,41
# ...                                                  ...              ...
# 10108  siconfi-cor_ContribuicaoDoServidorParaOPlanoDe...    27.610.496,00
# 10109   siconfi-cor_DeducaoDeReceitaParaFormacaoDoFUNDEB    95.676.468,00
# 10110            siconfi-cor_RREO3ReceitaCorrenteLiquida   903.629.507,00
# 10111  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...   903.629.507,00
# 10112  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...   903.629.507,00
#
# [10113 rows x 7 columns]

# %% [markdown]
# ## Limpeza de dados 2022

# %%
dados_2022 = pd.read_csv(r"C:\Users\gabri\OneDrive\Documentos\2 periodo\intro. cd\projetosiconf\finbraRREO2022.csv", sep =";", skiprows=5,  encoding="latin1")

# %%
dados_2022 =dados_2022.drop(columns=['Cod.IBGE', 'Coluna'])
dados_2022
# Out:
#                                    Instituição  UF  População  \
# 0      Prefeitura Municipal de Rio Branco - AC  AC     419452
# 1      Prefeitura Municipal de Rio Branco - AC  AC     419452
# 2      Prefeitura Municipal de Rio Branco - AC  AC     419452
# 3      Prefeitura Municipal de Rio Branco - AC  AC     419452
# 4      Prefeitura Municipal de Rio Branco - AC  AC     419452
# ...                                        ...  ..        ...
# 10485    Prefeitura Municipal de Teresina - PI  PI     871126
# 10486    Prefeitura Municipal de Teresina - PI  PI     871126
# 10487    Prefeitura Municipal de Teresina - PI  PI     871126
# 10488    Prefeitura Municipal de Teresina - PI  PI     871126
# 10489    Prefeitura Municipal de Teresina - PI  PI     871126
#
#                                                    Conta  \
# 0                                 RECEITAS CORRENTES (I)
# 1            Impostos, Taxas e Contribuições de Melhoria
# 2                                                   IPTU
# 3                                                    ISS
# 4                                                   ITBI
# ...                                                  ...
# 10485  Rendimentos de Aplicações de Recursos Previden...
# 10486         Dedução de Receita para Formação do FUNDEB
# 10487          RECEITA CORRENTE LÍQUIDA (III) = (I - II)
# 10488  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
# 10489  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
#
#                                   Identificador da Conta          Valor
# 0      siconfi-cor_ReceitasCorrentesLiquidasExcetoTra...   115006951,05
# 1      siconfi-cor_ReceitaTributariaLiquidaExcetoTran...    11780476,86
# 2      siconfi-cor_IPTULiquidoExcetoTransferenciasEFU...     1951472,82
# 3      siconfi-cor_ISSLiquidoExcetoTransferenciasEFUNDEB     7283480,56
# 4      siconfi-cor_ITBILiquidoExcetoTransferenciasEFU...       631476,7
# ...                                                  ...            ...
# 10485  siconfi-cor_RendimentosDeAplicacoesDeRecursosP...    44000000,00
# 10486   siconfi-cor_DeducaoDeReceitaParaFormacaoDoFUNDEB   273022000,00
# 10487            siconfi-cor_RREO3ReceitaCorrenteLiquida  3530495700,59
# 10488  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...  3530495700,59
# 10489  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...  3530495700,59
#
# [10490 rows x 6 columns]

# %%
dados_2022['Valor'] = dados_2022['Valor'].str.replace('.', '', regex=False) 
dados_2022['Valor'] = dados_2022['Valor'].str.replace(',', '.', regex=False)

dados_2022['Valor'] = pd.to_numeric(dados_2022['Valor'], errors='coerce')

dados_2022['Valor'] = dados_2022['Valor'].apply(lambda x: f' {x:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'))

# %%
dados_2022
# Out:
#                                    Instituição  UF  População  \
# 0      Prefeitura Municipal de Rio Branco - AC  AC     419452
# 1      Prefeitura Municipal de Rio Branco - AC  AC     419452
# 2      Prefeitura Municipal de Rio Branco - AC  AC     419452
# 3      Prefeitura Municipal de Rio Branco - AC  AC     419452
# 4      Prefeitura Municipal de Rio Branco - AC  AC     419452
# ...                                        ...  ..        ...
# 10485    Prefeitura Municipal de Teresina - PI  PI     871126
# 10486    Prefeitura Municipal de Teresina - PI  PI     871126
# 10487    Prefeitura Municipal de Teresina - PI  PI     871126
# 10488    Prefeitura Municipal de Teresina - PI  PI     871126
# 10489    Prefeitura Municipal de Teresina - PI  PI     871126
#
#                                                    Conta  \
# 0                                 RECEITAS CORRENTES (I)
# 1            Impostos, Taxas e Contribuições de Melhoria
# 2                                                   IPTU
# 3                                                    ISS
# 4                                                   ITBI
# ...                                                  ...
# 10485  Rendimentos de Aplicações de Recursos Previden...
# 10486         Dedução de Receita para Formação do FUNDEB
# 10487          RECEITA CORRENTE LÍQUIDA (III) = (I - II)
# 10488  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
# 10489  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
#
#                                   Identificador da Conta              Valor
# 0      siconfi-cor_ReceitasCorrentesLiquidasExcetoTra...     115.006.951,05
# 1      siconfi-cor_ReceitaTributariaLiquidaExcetoTran...      11.780.476,86
# 2      siconfi-cor_IPTULiquidoExcetoTransferenciasEFU...       1.951.472,82
# 3      siconfi-cor_ISSLiquidoExcetoTransferenciasEFUNDEB       7.283.480,56
# 4      siconfi-cor_ITBILiquidoExcetoTransferenciasEFU...         631.476,70
# ...                                                  ...                ...
# 10485  siconfi-cor_RendimentosDeAplicacoesDeRecursosP...      44.000.000,00
# 10486   siconfi-cor_DeducaoDeReceitaParaFormacaoDoFUNDEB     273.022.000,00
# 10487            siconfi-cor_RREO3ReceitaCorrenteLiquida   3.530.495.700,59
# 10488  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...   3.530.495.700,59
# 10489  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...   3.530.495.700,59
#
# [10490 rows x 6 columns]

# %%
dados_2022.insert(0, 'Ano', 2022)
dados_2022
# Out:
#         Ano                              Instituição  UF  População  \
# 0      2022  Prefeitura Municipal de Rio Branco - AC  AC     419452
# 1      2022  Prefeitura Municipal de Rio Branco - AC  AC     419452
# 2      2022  Prefeitura Municipal de Rio Branco - AC  AC     419452
# 3      2022  Prefeitura Municipal de Rio Branco - AC  AC     419452
# 4      2022  Prefeitura Municipal de Rio Branco - AC  AC     419452
# ...     ...                                      ...  ..        ...
# 10485  2022    Prefeitura Municipal de Teresina - PI  PI     871126
# 10486  2022    Prefeitura Municipal de Teresina - PI  PI     871126
# 10487  2022    Prefeitura Municipal de Teresina - PI  PI     871126
# 10488  2022    Prefeitura Municipal de Teresina - PI  PI     871126
# 10489  2022    Prefeitura Municipal de Teresina - PI  PI     871126
#
#                                                    Conta  \
# 0                                 RECEITAS CORRENTES (I)
# 1            Impostos, Taxas e Contribuições de Melhoria
# 2                                                   IPTU
# 3                                                    ISS
# 4                                                   ITBI
# ...                                                  ...
# 10485  Rendimentos de Aplicações de Recursos Previden...
# 10486         Dedução de Receita para Formação do FUNDEB
# 10487          RECEITA CORRENTE LÍQUIDA (III) = (I - II)
# 10488  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
# 10489  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
#
#                                   Identificador da Conta              Valor
# 0      siconfi-cor_ReceitasCorrentesLiquidasExcetoTra...     115.006.951,05
# 1      siconfi-cor_ReceitaTributariaLiquidaExcetoTran...      11.780.476,86
# 2      siconfi-cor_IPTULiquidoExcetoTransferenciasEFU...       1.951.472,82
# 3      siconfi-cor_ISSLiquidoExcetoTransferenciasEFUNDEB       7.283.480,56
# 4      siconfi-cor_ITBILiquidoExcetoTransferenciasEFU...         631.476,70
# ...                                                  ...                ...
# 10485  siconfi-cor_RendimentosDeAplicacoesDeRecursosP...      44.000.000,00
# 10486   siconfi-cor_DeducaoDeReceitaParaFormacaoDoFUNDEB     273.022.000,00
# 10487            siconfi-cor_RREO3ReceitaCorrenteLiquida   3.530.495.700,59
# 10488  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...   3.530.495.700,59
# 10489  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...   3.530.495.700,59
#
# [10490 rows x 7 columns]

# %% [markdown]
# ## Limpeza de dados 2023

# %%
dados_2023 = pd.read_csv(r"C:\Users\gabri\OneDrive\Documentos\2 periodo\intro. cd\projetosiconf\finbraRREO2023.csv", sep =";", skiprows=5,  encoding="latin1")

# %%
dados_2023 =dados_2023.drop(columns=['Cod.IBGE', 'Coluna'])
dados_2023
# Out:
#                                  Instituição  UF  População  \
# 0      Prefeitura Municipal de Salvador - BA  BA    2900319
# 1      Prefeitura Municipal de Salvador - BA  BA    2900319
# 2      Prefeitura Municipal de Salvador - BA  BA    2900319
# 3      Prefeitura Municipal de Salvador - BA  BA    2900319
# 4      Prefeitura Municipal de Salvador - BA  BA    2900319
# ...                                      ...  ..        ...
# 10741    Prefeitura Municipal de Cuiabá - MT  MT     623614
# 10742    Prefeitura Municipal de Cuiabá - MT  MT     623614
# 10743    Prefeitura Municipal de Cuiabá - MT  MT     623614
# 10744    Prefeitura Municipal de Cuiabá - MT  MT     623614
# 10745    Prefeitura Municipal de Cuiabá - MT  MT     623614
#
#                                                    Conta  \
# 0                                 RECEITAS CORRENTES (I)
# 1            Impostos, Taxas e Contribuições de Melhoria
# 2                                                   IPTU
# 3                                                    ISS
# 4                                                   ITBI
# ...                                                  ...
# 10741          RECEITA CORRENTE LÍQUIDA (III) = (I - II)
# 10742  ( - ) Transferências obrigatórias da União rel...
# 10743  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
# 10744  ( - ) Transferências obrigatórias da União rel...
# 10745  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
#
#                                   Identificador da Conta          Valor
# 0      siconfi-cor_ReceitasCorrentesLiquidasExcetoTra...   748076602,18
# 1      siconfi-cor_ReceitaTributariaLiquidaExcetoTran...   260095848,26
# 2      siconfi-cor_IPTULiquidoExcetoTransferenciasEFU...    63158513,88
# 3      siconfi-cor_ISSLiquidoExcetoTransferenciasEFUNDEB   118868688,57
# 4      siconfi-cor_ITBILiquidoExcetoTransferenciasEFU...    18068577,33
# ...                                                  ...            ...
# 10741            siconfi-cor_RREO3ReceitaCorrenteLiquida  3798349490,95
# 10742  siconfi-cor_RREO3TransferenciasObrigatoriasDaU...    58700000,00
# 10743  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...  3739649490,95
# 10744  siconfi-cor_RREO3TransferenciasObrigatoriasDaU...    12387000,00
# 10745  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...  3727262490,95
#
# [10746 rows x 6 columns]

# %%
dados_2023['Valor'] = dados_2023['Valor'].str.replace('.', '', regex=False) 
dados_2023['Valor'] = dados_2023['Valor'].str.replace(',', '.', regex=False)

dados_2023['Valor'] = pd.to_numeric(dados_2023['Valor'], errors='coerce')

dados_2023['Valor'] = dados_2023['Valor'].apply(lambda x: f' {x:,.2f}'.replace(',', 'X').replace('.', ',').replace('X', '.'))

# %%
dados_2023
# Out:
#                                  Instituição  UF  População  \
# 0      Prefeitura Municipal de Salvador - BA  BA    2900319
# 1      Prefeitura Municipal de Salvador - BA  BA    2900319
# 2      Prefeitura Municipal de Salvador - BA  BA    2900319
# 3      Prefeitura Municipal de Salvador - BA  BA    2900319
# 4      Prefeitura Municipal de Salvador - BA  BA    2900319
# ...                                      ...  ..        ...
# 10741    Prefeitura Municipal de Cuiabá - MT  MT     623614
# 10742    Prefeitura Municipal de Cuiabá - MT  MT     623614
# 10743    Prefeitura Municipal de Cuiabá - MT  MT     623614
# 10744    Prefeitura Municipal de Cuiabá - MT  MT     623614
# 10745    Prefeitura Municipal de Cuiabá - MT  MT     623614
#
#                                                    Conta  \
# 0                                 RECEITAS CORRENTES (I)
# 1            Impostos, Taxas e Contribuições de Melhoria
# 2                                                   IPTU
# 3                                                    ISS
# 4                                                   ITBI
# ...                                                  ...
# 10741          RECEITA CORRENTE LÍQUIDA (III) = (I - II)
# 10742  ( - ) Transferências obrigatórias da União rel...
# 10743  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
# 10744  ( - ) Transferências obrigatórias da União rel...
# 10745  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
#
#                                   Identificador da Conta              Valor
# 0      siconfi-cor_ReceitasCorrentesLiquidasExcetoTra...     748.076.602,18
# 1      siconfi-cor_ReceitaTributariaLiquidaExcetoTran...     260.095.848,26
# 2      siconfi-cor_IPTULiquidoExcetoTransferenciasEFU...      63.158.513,88
# 3      siconfi-cor_ISSLiquidoExcetoTransferenciasEFUNDEB     118.868.688,57
# 4      siconfi-cor_ITBILiquidoExcetoTransferenciasEFU...      18.068.577,33
# ...                                                  ...                ...
# 10741            siconfi-cor_RREO3ReceitaCorrenteLiquida   3.798.349.490,95
# 10742  siconfi-cor_RREO3TransferenciasObrigatoriasDaU...      58.700.000,00
# 10743  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...   3.739.649.490,95
# 10744  siconfi-cor_RREO3TransferenciasObrigatoriasDaU...      12.387.000,00
# 10745  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...   3.727.262.490,95
#
# [10746 rows x 6 columns]

# %%
dados_2023.insert(0, 'Ano', 2023)
dados_2023
# Out:
#         Ano                            Instituição  UF  População  \
# 0      2023  Prefeitura Municipal de Salvador - BA  BA    2900319
# 1      2023  Prefeitura Municipal de Salvador - BA  BA    2900319
# 2      2023  Prefeitura Municipal de Salvador - BA  BA    2900319
# 3      2023  Prefeitura Municipal de Salvador - BA  BA    2900319
# 4      2023  Prefeitura Municipal de Salvador - BA  BA    2900319
# ...     ...                                    ...  ..        ...
# 10741  2023    Prefeitura Municipal de Cuiabá - MT  MT     623614
# 10742  2023    Prefeitura Municipal de Cuiabá - MT  MT     623614
# 10743  2023    Prefeitura Municipal de Cuiabá - MT  MT     623614
# 10744  2023    Prefeitura Municipal de Cuiabá - MT  MT     623614
# 10745  2023    Prefeitura Municipal de Cuiabá - MT  MT     623614
#
#                                                    Conta  \
# 0                                 RECEITAS CORRENTES (I)
# 1            Impostos, Taxas e Contribuições de Melhoria
# 2                                                   IPTU
# 3                                                    ISS
# 4                                                   ITBI
# ...                                                  ...
# 10741          RECEITA CORRENTE LÍQUIDA (III) = (I - II)
# 10742  ( - ) Transferências obrigatórias da União rel...
# 10743  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
# 10744  ( - ) Transferências obrigatórias da União rel...
# 10745  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
#
#                                   Identificador da Conta              Valor
# 0      siconfi-cor_ReceitasCorrentesLiquidasExcetoTra...     748.076.602,18
# 1      siconfi-cor_ReceitaTributariaLiquidaExcetoTran...     260.095.848,26
# 2      siconfi-cor_IPTULiquidoExcetoTransferenciasEFU...      63.158.513,88
# 3      siconfi-cor_ISSLiquidoExcetoTransferenciasEFUNDEB     118.868.688,57
# 4      siconfi-cor_ITBILiquidoExcetoTransferenciasEFU...      18.068.577,33
# ...                                                  ...                ...
# 10741            siconfi-cor_RREO3ReceitaCorrenteLiquida   3.798.349.490,95
# 10742  siconfi-cor_RREO3TransferenciasObrigatoriasDaU...      58.700.000,00
# 10743  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...   3.739.649.490,95
# 10744  siconfi-cor_RREO3TransferenciasObrigatoriasDaU...      12.387.000,00
# 10745  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...   3.727.262.490,95
#
# [10746 rows x 7 columns]

# %% [markdown]
# ## Juntando os datasets

# %%
dados = pd.concat([dados_2021, dados_2022, dados_2023], ignore_index=True)
dados.head()
# Out:
#     Ano                               Instituição  UF  População  \
# 0  2021  Prefeitura Municipal de Porto Velho - RO  RO     539354
# 1  2021  Prefeitura Municipal de Porto Velho - RO  RO     539354
# 2  2021  Prefeitura Municipal de Porto Velho - RO  RO     539354
# 3  2021  Prefeitura Municipal de Porto Velho - RO  RO     539354
# 4  2021  Prefeitura Municipal de Porto Velho - RO  RO     539354
#
#                                          Conta  \
# 0                       RECEITAS CORRENTES (I)
# 1  Impostos, Taxas e Contribuições de Melhoria
# 2                                         IPTU
# 3                                          ISS
# 4                                         ITBI
#
#                               Identificador da Conta            Valor
# 0  siconfi-cor_ReceitasCorrentesLiquidasExcetoTra...   168.295.392,69
# 1  siconfi-cor_ReceitaTributariaLiquidaExcetoTran...    46.427.054,97
# 2  siconfi-cor_IPTULiquidoExcetoTransferenciasEFU...    16.276.431,81
# 3  siconfi-cor_ISSLiquidoExcetoTransferenciasEFUNDEB    11.369.867,25
# 4  siconfi-cor_ITBILiquidoExcetoTransferenciasEFU...     1.220.253,41

# %%
dados.tail()
# Out:
#         Ano                          Instituição  UF  População  \
# 31344  2023  Prefeitura Municipal de Cuiabá - MT  MT     623614
# 31345  2023  Prefeitura Municipal de Cuiabá - MT  MT     623614
# 31346  2023  Prefeitura Municipal de Cuiabá - MT  MT     623614
# 31347  2023  Prefeitura Municipal de Cuiabá - MT  MT     623614
# 31348  2023  Prefeitura Municipal de Cuiabá - MT  MT     623614
#
#                                                    Conta  \
# 31344          RECEITA CORRENTE LÍQUIDA (III) = (I - II)
# 31345  ( - ) Transferências obrigatórias da União rel...
# 31346  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
# 31347  ( - ) Transferências obrigatórias da União rel...
# 31348  RECEITA CORRENTE LÍQUIDA AJUSTADA PARA CÁLCULO...
#
#                                   Identificador da Conta              Valor
# 31344            siconfi-cor_RREO3ReceitaCorrenteLiquida   3.798.349.490,95
# 31345  siconfi-cor_RREO3TransferenciasObrigatoriasDaU...      58.700.000,00
# 31346  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...   3.739.649.490,95
# 31347  siconfi-cor_RREO3TransferenciasObrigatoriasDaU...      12.387.000,00
# 31348  siconfi-cor_RREO3ReceitaCorrenteLiquidaAjustad...   3.727.262.490,95

# %%
dados.to_csv('dados_totais.csv', index=False)
